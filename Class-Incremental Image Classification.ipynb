# %%
! find "data/Train" -type f | wc -l
! find "data/Val" -type f | wc -l
# Out:
# 2960
# 886

# %%
! find "data/Train/phase_1/" -type f | wc -l
! find "data/Train/phase_2/" -type f | wc -l
! find "data/Train/phase_3/" -type f | wc -l
! find "data/Train/phase_4/" -type f | wc -l
! find "data/Train/phase_5/" -type f | wc -l
! find "data/Train/phase_6/" -type f | wc -l
! find "data/Train/phase_7/" -type f | wc -l
! find "data/Train/phase_8/" -type f | wc -l
! find "data/Train/phase_9/" -type f | wc -l
! find "data/Train/phase_10/" -type f | wc -l
# Out:
# 294
# 299
# 293
# 292
# 297
# 299
# 297
# 298
# 293
# 298

# %%
from utils import preprocess_image, CustomImageDataset, NeuralNetwork, get_training_datasets, get_k_fold_training_datasets, trainingImageDatasets
# Out:
# device:  cuda

# %%
len(trainingImageDatasets[0]), len(trainingImageDatasets[9])
# Out:
# (294, 298)

# %%
train_set, val_set = get_k_fold_training_datasets(1, 0)
train_set, val_set, len(train_set), len(val_set)
# Out:
# (<torch.utils.data.dataset.Subset at 0x7f231a90f910>,
#  <torch.utils.data.dataset.Subset at 0x7f231a90f950>,
#  235,
#  59)

# %%
train_set, val_set = get_k_fold_training_datasets(1, 4)
train_set, val_set, len(train_set), len(val_set)
# Out:
# (<torch.utils.data.dataset.Subset at 0x7f231a959610>,
#  <torch.utils.data.dataset.Subset at 0x7f231a959450>,
#  236,
#  58)

# %%
train_set, val_set = get_k_fold_training_datasets(2, 0)
train_set, val_set, len(train_set), len(val_set)
# Out:
# (<torch.utils.data.dataset.ConcatDataset at 0x7f380aa6de50>,
#  <torch.utils.data.dataset.ConcatDataset at 0x7f380aa6d910>,
#  279,
#  70)

# %%
train_set, val_set = get_k_fold_training_datasets(10, 4)
train_set, val_set, len(train_set), len(val_set)
# Out:
# (<torch.utils.data.dataset.ConcatDataset at 0x7f380236db10>,
#  <torch.utils.data.dataset.ConcatDataset at 0x7f380236d210>,
#  599,
#  149)

# %%
train_set, val_set = get_training_datasets(1)
train_set, val_set, len(train_set), len(val_set)
# Out:
# (<torch.utils.data.dataset.Subset at 0x7f993ea0b310>,
#  <torch.utils.data.dataset.Subset at 0x7f98191e7cd0>,
#  205,
#  89)

# %%
train_set2, val_set2 = get_training_datasets(2, [train_set], [val_set])
len(train_set2), len(val_set2)
# Out:
# (259, 179)

# %%
train_set3, val_set3 = get_training_datasets(2, [train_set, train_set2], [val_set, val_set2])
len(train_set3), len(val_set3)
# Out:
# (309, 269)

# %%
dataset = CustomImageDataset(0)
len(dataset)
# Out:
# not found:  data/Val/789.jpg
# 886

# %%
dataset[885]
# Out:
# (<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x384>, '886.jpg')

# %%
dataset = CustomImageDataset(1)
len(dataset), dataset[0]
# Out:
# (294, (<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=357x500>, 0))

# %%
dataset = CustomImageDataset(2)
len(dataset), dataset[20], dataset[50]
# Out:
# (349,
#  (<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=480x371>, 4),
#  (<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x375>, 10))

# %%
dataset = CustomImageDataset(10)
len(dataset), dataset[203], dataset[700]
# Out:
# (748,
#  (<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x333>, 40),
#  (<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x360>, 98))

# %%
dataset[700][0]
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x360>

# %%
dataset = CustomImageDataset(5, transform=preprocess_image)
len(dataset)
# Out:
# 497

# %%
dataset[405]
# Out:
# (tensor([[[0.6563, 0.6392, 0.6221,  ..., 0.8104, 0.8276, 0.8104],
#           [0.5878, 0.5707, 0.5536,  ..., 0.7591, 0.7762, 0.7762],
#           [0.5536, 0.5364, 0.5364,  ..., 0.6221, 0.6392, 0.6906],
#           ...,
#           [0.7762, 0.7762, 0.8276,  ..., 1.0673, 1.1015, 1.0844],
#           [0.8104, 0.8276, 0.8276,  ..., 1.0502, 1.0673, 1.0673],
#           [0.7933, 0.7933, 0.8104,  ..., 1.0159, 1.0502, 1.0331]],
#
#          [[0.7829, 0.8529, 0.8179,  ..., 0.9055, 0.9055, 0.8880],
#           [0.8004, 0.8004, 0.7829,  ..., 0.8529, 0.8354, 0.8179],
#           [0.7479, 0.7129, 0.7654,  ..., 0.8354, 0.8354, 0.8179],
#           ...,
#           [1.1155, 1.0455, 1.1155,  ..., 1.3431, 1.3431, 1.3431],
#           [1.0455, 1.0630, 1.0805,  ..., 1.3606, 1.3431, 1.3256],
#           [1.0455, 1.0280, 1.0455,  ..., 1.3431, 1.3431, 1.2906]],
#
#          [[1.8557, 1.3502, 1.2282,  ..., 1.2108, 1.2282, 1.2108],
#           [1.3154, 1.2108, 1.1411,  ..., 1.1411, 1.2805, 1.3328],
#           [1.5594, 1.5768, 1.2980,  ..., 1.1237, 1.1411, 1.3851],
#           ...,
#           [1.5245, 1.9080, 1.9428,  ..., 2.0997, 2.1868, 2.0648],
#           [1.9254, 1.9777, 1.9428,  ..., 2.1171, 2.1346, 2.0648],
#           [1.8208, 1.9080, 2.0125,  ..., 2.0648, 2.1346, 2.0125]]]),
#  46)

# %%
dataset[400][0]
# Out:
# tensor([[[-0.9020, -0.9534, -0.9192,  ..., -0.9192, -0.9705, -0.9363],
#          [-0.9363, -0.8678, -0.8849,  ..., -0.9020, -1.0219, -0.9705],
#          [-0.9020, -0.9020, -0.9020,  ..., -0.9705, -1.0219, -1.0219],
#          ...,
#          [-1.8610, -1.8097, -1.7925,  ..., -1.8782, -1.8953, -1.8782],
#          [-1.8439, -1.8097, -1.7754,  ..., -1.8953, -1.8953, -1.9124],
#          [-1.8782, -1.8782, -1.7754,  ..., -1.8953, -1.9124, -1.8953]],
#
#         [[-0.8978, -0.8803, -0.8627,  ..., -0.9153, -0.9503, -0.9153],
#          [-0.9678, -0.8803, -0.8102,  ..., -0.9153, -1.0028, -0.9328],
#          [-0.8803, -0.8803, -0.8452,  ..., -0.9678, -0.9853, -0.9853],
#          ...,
#          [-1.8081, -1.7906, -1.7731,  ..., -1.8256, -1.8431, -1.8431],
#          [-1.8081, -1.7731, -1.7381,  ..., -1.8256, -1.8431, -1.8606],
#          [-1.8256, -1.8431, -1.7381,  ..., -1.8782, -1.8431, -1.8782]],
#
#         [[ 0.3045, -0.0615, -0.2881,  ..., -0.2358, -0.3404, -0.1487],
#          [ 0.0953,  0.1651, -0.3055,  ..., -0.0964, -0.3753, -0.2707],
#          [-0.1312, -0.0615, -0.3404,  ..., -0.2010, -0.3578, -0.3927],
#          ...,
#          [-1.2641, -1.2119, -1.3339,  ..., -1.2816, -1.1944, -1.0898],
#          [-1.4210, -1.3339, -1.2816,  ..., -1.2467, -1.1944, -0.9678],
#          [-1.5081, -1.4559, -1.1073,  ..., -0.9330, -1.2119, -0.7238]]])

# %%
model = NeuralNetwork(100)
model.base_model
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Sequential(
#     (0): Dropout(p=0.2, inplace=False)
#     (1): Linear(in_features=2048, out_features=100, bias=True)
#   )
# )

# %%
model.base_model.fc
# Out:
# Sequential(
#   (0): Dropout(p=0.2, inplace=False)
#   (1): Linear(in_features=2048, out_features=100, bias=True)
# )

# %%
pytorch_total_params = sum(p.numel() for p in model.base_model.parameters() if p.requires_grad)
pytorch_total_params
# Out:
# 86947236

# %%
# %%time
# !python train.py --epochs=10 --batch=32 --phase=1
# Out:
# device:  cuda
# classes:  10
# epochs:  10
# batch:  32
# phase:  1
# checkpoint:  0
# Starting epoch 1
# epoch: 1 train: loss:2.074
# epoch: 1 test: weighted f1 0.870
# saved checkpoint: /mnt/c/Users/dongh/OneDrive - Singapore Management University/code/courses/01_CS701-G1-Deep Learning and Vision/project/cs701/data/checkpoints_phase_1/checkpoint-001.pth
# Starting epoch 2
# epoch: 2 train: loss:1.763
# epoch: 2 test: weighted f1 0.916
# saved checkpoint: /mnt/c/Users/dongh/OneDrive - Singapore Management University/code/courses/01_CS701-G1-Deep Learning and Vision/project/cs701/data/checkpoints_phase_1/checkpoint-002.pth
# Starting epoch 3
# epoch: 3 train: loss:1.646
# epoch: 3 test: weighted f1 0.916
# saved checkpoint: /mnt/c/Users/dongh/OneDrive - Singapore Management University/code/courses/01_CS701-G1-Deep Learning and Vision/project/cs701/data/checkpoints_phase_1/checkpoint-003.pth
# Starting epoch 4
# epoch: 4 train: loss:1.568
# epoch: 4 test: weighted f1 0.934
# saved checkpoint: /mnt/c/Users/dongh/OneDrive - Singapore Management University/code/courses/01_CS701-G1-Deep Learning and Vision/project/cs701/data/checkpoints_phase_1/checkpoint-004.pth
# Starting epoch 5
# epoch: 5 train: loss:1.526
# epoch: 5 test: weighted f1 0.922
# saved checkpoint: /mnt/c/Users/dongh/OneDrive - Singapore Management University/code/courses/01_CS701-G1-Deep Learning and Vision/project/cs701/data/checkpoints_phase_1/checkpoint-005.pth
# Starting epoch 6
# epoch: 6 train: loss:1.501
# epoch: 6 test: weighted f1 0.945
# saved checkpoint: /mnt/c/Users/dongh/OneDrive - Singapore Management University/code/courses/01_CS701-G1-Deep Learning and Vision/project/cs701/data/checkpoints_phase_1/checkpoint-006.pth
# Starting epoch 7
# epoch: 7 train: loss:1.488
# epoch: 7 test: weighted f1 0.945
# saved checkpoint: /mnt/c/Users/dongh/OneDrive - Singapore Management University/code/courses/01_CS701-G1-Deep Learning and Vision/project/cs701/data/checkpoints_phase_1/checkpoint-007.pth
# Starting epoch 8
# epoch: 8 train: loss:1.481
# epoch: 8 test: weighted f1 0.934
# saved checkpoint: /mnt/c/Users/dongh/OneDrive - Singapore Management University/code/courses/01_CS701-G1-Deep Learning and Vision/project/cs701/data/checkpoints_phase_1/checkpoint-008.pth
# Starting epoch 9
# epoch: 9 train: loss:1.476
# epoch: 9 test: weighted f1 0.944
# saved checkpoint: /mnt/c/Users/dongh/OneDrive - Singapore Management University/code/courses/01_CS701-G1-Deep Learning and Vision/project/cs701/data/checkpoints_phase_1/checkpoint-009.pth
# Starting epoch 10
# epoch:10 train: loss:1.474
# epoch:10 test: weighted f1 0.944
# saved checkpoint: /mnt/c/Users/dongh/OneDrive - Singapore Management University/code/courses/01_CS701-G1-Deep Learning and Vision/project/cs701/data/checkpoints_phase_1/checkpoint-010.pth
# Training is completed in 0.0 hours, 6.0 minutes, 37.419 seconds
# CPU times: user 5.26 s, sys: 1.49 s, total: 6.76 s
# Wall time: 6min 40s

# %%
# %%time
# !python validate.py --batch=32 --phase=1
# Out:
# device:  cuda
# classes:  10
# checkpoint:  0
# batch:  32
# phase:  1
# loaded checkpoint: /mnt/c/Users/dongh/OneDrive - Singapore Management University/code/courses/01_CS701-G1-Deep Learning and Vision/project/cs701/data/checkpoints_phase_1/checkpoint-006.pth
# checkpoint: 6 test: weighted f1 0.945
# not found:  data/Val/789.jpg
# 886 results saved to: /mnt/c/Users/dongh/OneDrive - Singapore Management University/code/courses/01_CS701-G1-Deep Learning and Vision/project/cs701/results/result_1.txt
# Validation is completed in 0.0 hours, 0.0 minutes, 46.456 seconds
# CPU times: user 573 ms, sys: 160 ms, total: 733 ms
# Wall time: 49.3 s

# %%
# %%time
# !python train.py --epochs=20 --batch=32 --phase=2
# Out:
# device:  cuda
# classes:  20
# epochs:  20
# batch:  32
# phase:  2
# checkpoint:  0
# loaded checkpoint: /mnt/c/Users/dongh/OneDrive - Singapore Management University/code/courses/01_CS701-G1-Deep Learning and Vision/project/cs701/data/checkpoints_phase_1/checkpoint-006.pth
# Starting epoch 1
# epoch: 1 train: loss:2.645
# epoch: 1 test: weighted f1 0.598
# saved checkpoint: /mnt/c/Users/dongh/OneDrive - Singapore Management University/code/courses/01_CS701-G1-Deep Learning and Vision/project/cs701/data/checkpoints_phase_2/checkpoint-001.pth
# Starting epoch 2
# epoch: 2 train: loss:2.398
# epoch: 2 test: weighted f1 0.793
# saved checkpoint: /mnt/c/Users/dongh/OneDrive - Singapore Management University/code/courses/01_CS701-G1-Deep Learning and Vision/project/cs701/data/checkpoints_phase_2/checkpoint-002.pth
# Starting epoch 3
# epoch: 3 train: loss:2.299
# epoch: 3 test: weighted f1 0.732
# saved checkpoint: /mnt/c/Users/dongh/OneDrive - Singapore Management University/code/courses/01_CS701-G1-Deep Learning and Vision/project/cs701/data/checkpoints_phase_2/checkpoint-003.pth
# Starting epoch 4
# epoch: 4 train: loss:2.230
# epoch: 4 test: weighted f1 0.741
# saved checkpoint: /mnt/c/Users/dongh/OneDrive - Singapore Management University/code/courses/01_CS701-G1-Deep Learning and Vision/project/cs701/data/checkpoints_phase_2/checkpoint-004.pth
# Starting epoch 5
# epoch: 5 train: loss:2.182
# epoch: 5 test: weighted f1 0.751
# saved checkpoint: /mnt/c/Users/dongh/OneDrive - Singapore Management University/code/courses/01_CS701-G1-Deep Learning and Vision/project/cs701/data/checkpoints_phase_2/checkpoint-005.pth
# Starting epoch 6
# epoch: 6 train: loss:2.146
# epoch: 6 test: weighted f1 0.760
# saved checkpoint: /mnt/c/Users/dongh/OneDrive - Singapore Management University/code/courses/01_CS701-G1-Deep Learning and Vision/project/cs701/data/checkpoints_phase_2/checkpoint-006.pth
# Starting epoch 7
# epoch: 7 train: loss:2.125
# epoch: 7 test: weighted f1 0.795
# saved checkpoint: /mnt/c/Users/dongh/OneDrive - Singapore Management University/code/courses/01_CS701-G1-Deep Learning and Vision/project/cs701/data/checkpoints_phase_2/checkpoint-007.pth
# Starting epoch 8
# epoch: 8 train: loss:2.113
# epoch: 8 test: weighted f1 0.809
# saved checkpoint: /mnt/c/Users/dongh/OneDrive - Singapore Management University/code/courses/01_CS701-G1-Deep Learning and Vision/project/cs701/data/checkpoints_phase_2/checkpoint-008.pth
# Starting epoch 9
# epoch: 9 train: loss:2.105
# epoch: 9 test: weighted f1 0.812
# saved checkpoint: /mnt/c/Users/dongh/OneDrive - Singapore Management University/code/courses/01_CS701-G1-Deep Learning and Vision/project/cs701/data/checkpoints_phase_2/checkpoint-009.pth
# Starting epoch 10
# epoch:10 train: loss:2.101
# epoch:10 test: weighted f1 0.822
# saved checkpoint: /mnt/c/Users/dongh/OneDrive - Singapore Management University/code/courses/01_CS701-G1-Deep Learning and Vision/project/cs701/data/checkpoints_phase_2/checkpoint-010.pth
# Starting epoch 11
# epoch:11 train: loss:2.099
# epoch:11 test: weighted f1 0.829
# saved checkpoint: /mnt/c/Users/dongh/OneDrive - Singapore Management University/code/courses/01_CS701-G1-Deep Learning and Vision/project/cs701/data/checkpoints_phase_2/checkpoint-011.pth
# Starting epoch 12
# epoch:12 train: loss:2.098
# epoch:12 test: weighted f1 0.809
# saved checkpoint: /mnt/c/Users/dongh/OneDrive - Singapore Management University/code/courses/01_CS701-G1-Deep Learning and Vision/project/cs701/data/checkpoints_phase_2/checkpoint-012.pth
# Starting epoch 13
# epoch:13 train: loss:2.094
# epoch:13 test: weighted f1 0.838
# saved checkpoint: /mnt/c/Users/dongh/OneDrive - Singapore Management University/code/courses/01_CS701-G1-Deep Learning and Vision/project/cs701/data/checkpoints_phase_2/checkpoint-013.pth
# Starting epoch 14
# epoch:14 train: loss:2.090
# epoch:14 test: weighted f1 0.828
# saved checkpoint: /mnt/c/Users/dongh/OneDrive - Singapore Management University/code/courses/01_CS701-G1-Deep Learning and Vision/project/cs701/data/checkpoints_phase_2/checkpoint-014.pth
# Starting epoch 15
# epoch:15 train: loss:2.088
# epoch:15 test: weighted f1 0.811
# saved checkpoint: /mnt/c/Users/dongh/OneDrive - Singapore Management University/code/courses/01_CS701-G1-Deep Learning and Vision/project/cs701/data/checkpoints_phase_2/checkpoint-015.pth
# Starting epoch 16
# epoch:16 train: loss:2.087
# epoch:16 test: weighted f1 0.838
# saved checkpoint: /mnt/c/Users/dongh/OneDrive - Singapore Management University/code/courses/01_CS701-G1-Deep Learning and Vision/project/cs701/data/checkpoints_phase_2/checkpoint-016.pth
# Starting epoch 17
# epoch:17 train: loss:2.086
# epoch:17 test: weighted f1 0.811
# saved checkpoint: /mnt/c/Users/dongh/OneDrive - Singapore Management University/code/courses/01_CS701-G1-Deep Learning and Vision/project/cs701/data/checkpoints_phase_2/checkpoint-017.pth
# Starting epoch 18
# epoch:18 train: loss:2.085
# epoch:18 test: weighted f1 0.821
# saved checkpoint: /mnt/c/Users/dongh/OneDrive - Singapore Management University/code/courses/01_CS701-G1-Deep Learning and Vision/project/cs701/data/checkpoints_phase_2/checkpoint-018.pth
# Starting epoch 19
# epoch:19 train: loss:2.084
# epoch:19 test: weighted f1 0.813
# saved checkpoint: /mnt/c/Users/dongh/OneDrive - Singapore Management University/code/courses/01_CS701-G1-Deep Learning and Vision/project/cs701/data/checkpoints_phase_2/checkpoint-019.pth
# Starting epoch 20
# epoch:20 train: loss:2.083
# epoch:20 test: weighted f1 0.821
# saved checkpoint: /mnt/c/Users/dongh/OneDrive - Singapore Management University/code/courses/01_CS701-G1-Deep Learning and Vision/project/cs701/data/checkpoints_phase_2/checkpoint-020.pth
# Training is completed in 0.0 hours, 15.0 minutes, 36.641 seconds
# CPU times: user 11.9 s, sys: 3.22 s, total: 15.2 s
# Wall time: 15min 40s

# %%
# %%time
# !python validate.py --batch=32 --phase=2
# Out:
# device:  cuda
# classes:  20
# checkpoint:  0
# batch:  32
# phase:  2
# loaded checkpoint: /mnt/c/Users/dongh/OneDrive - Singapore Management University/code/courses/01_CS701-G1-Deep Learning and Vision/project/cs701/data/checkpoints_phase_2/checkpoint-013.pth
# checkpoint:13 test: weighted f1 0.991
# not found:  data/Val/789.jpg
# 886 results saved to: /mnt/c/Users/dongh/OneDrive - Singapore Management University/code/courses/01_CS701-G1-Deep Learning and Vision/project/cs701/results/result_2.txt
# Validation is completed in 0.0 hours, 0.0 minutes, 45.863 seconds
# CPU times: user 606 ms, sys: 129 ms, total: 734 ms
# Wall time: 47.9 s

# %%
from torchvision import models

resnet152 = models.resnet152(pretrained=True)
resnet152
# Out:
# /Users/inflaton/miniconda3/envs/cs701/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /Users/inflaton/miniconda3/envs/cs701/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet152_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet152_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet152-394f9c45.pth" to /Users/inflaton/.cache/torch/hub/checkpoints/resnet152-394f9c45.pth
# 100%|██████████| 230M/230M [00:42<00:00, 5.66MB/s]
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (6): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (7): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (6): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (7): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (8): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (9): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (10): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (11): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (12): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (13): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (14): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (15): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (16): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (17): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (18): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (19): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (20): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (21): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (22): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (23): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (24): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (25): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (26): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (27): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (28): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (29): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (30): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (31): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (32): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (33): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (34): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (35): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=1000, bias=True)
# )

# %%
# !./train.sh
# Out:
# Current Directory:
# /home/inflaton/code/courses/cs701
# Sun Oct 22 06:08:41 2023
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.103                Driver Version: 537.13       CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce RTX 4080 ...    On  | 00000000:01:00.0 Off |                  N/A |
# | N/A   52C    P8               2W / 150W |      0MiB / 12282MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+
# Linux Donghao-Win 5.10.102.1-microsoft-standard-WSL2 #1 SMP Wed Mar 2 00:30:59 UTC 2022 x86_64 x86_64 x86_64 GNU/Linux
# PRETTY_NAME="Ubuntu 22.04.3 LTS"
# NAME="Ubuntu"
# VERSION_ID="22.04"
# VERSION="22.04.3 LTS (Jammy Jellyfish)"
# VERSION_CODENAME=jammy
# ID=ubuntu
# ID_LIKE=debian
# HOME_URL="https://www.ubuntu.com/"
# SUPPORT_URL="https://help.ubuntu.com/"
# BUG_REPORT_URL="https://bugs.launchpad.net/ubuntu/"
# PRIVACY_POLICY_URL="https://www.ubuntu.com/legal/terms-and-policies/privacy-policy"
# UBUNTU_CODENAME=jammy
# Architecture:            x86_64
#   CPU op-mode(s):        32-bit, 64-bit
#   Address sizes:         39 bits physical, 48 bits virtual
#   Byte Order:            Little Endian
# CPU(s):                  24
#   On-line CPU(s) list:   0-23
# Vendor ID:               GenuineIntel
#   Model name:            13th Gen Intel(R) Core(TM) i9-13900HX
#     CPU family:          6
#     Model:               183
#     Thread(s) per core:  2
#     Core(s) per socket:  12
#     Socket(s):           1
#     Stepping:            1
#     BogoMIPS:            4838.39
#     Flags:               fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mc
#                          a cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscal
#                          l nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopo
#                          logy tsc_reliable nonstop_tsc cpuid pni pclmulqdq vmx s
#                          sse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt ts
#                          c_deadline_timer aes xsave avx f16c rdrand hypervisor l
#                          ahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb
#                          stibp ibrs_enhanced tpr_shadow vnmi ept vpid ept_ad fsg
#                          sbase tsc_adjust bmi1 avx2 smep bmi2 erms invpcid rdsee
#                          d adx smap clflushopt clwb sha_ni xsaveopt xsavec xgetb
#                          v1 xsaves umip waitpkg gfni vaes vpclmulqdq rdpid movdi
#                          ri movdir64b fsrm serialize flush_l1d arch_capabilities
# Virtualization features:
#   Virtualization:        VT-x
#   Hypervisor vendor:     Microsoft
#   Virtualization type:   full
# Caches (sum of all):
#   L1d:                   576 KiB (12 instances)
#   L1i:                   384 KiB (12 instances)
#   L2:                    24 MiB (12 instances)
#   L3:                    36 MiB (1 instance)
# Vulnerabilities:
#   Itlb multihit:         Not affected
#   L1tf:                  Not affected
#   Mds:                   Not affected
#   Meltdown:              Not affected
#   Spec store bypass:     Mitigation; Speculative Store Bypass disabled via prctl
#                           and seccomp
#   Spectre v1:            Mitigation; usercopy/swapgs barriers and __user pointer
#                           sanitization
#   Spectre v2:            Mitigation; Enhanced IBRS, IBPB conditional, RSB fillin
#                          g
#   Srbds:                 Not affected
#   Tsx async abort:       Not affected
# MemTotal:       49334668 kB
# Running python train-all-phases-k-fold.py --epochs=30 --batch=64
# device:  cuda
# epochs:  30
# batch:  64
# phase:  1
# classes:  10
# fold:  1
# Starting epoch 1
# phase: 1 fold: 1 epoch: 1 - loss:2.301
# phase: 1 fold: 1 epoch: 1 - accuracy:0.112
# saved checkpoint: /home/inflaton/code/courses/cs701/data/checkpoints_phase_1/checkpoint-001.pth
# Starting epoch 2
# phase: 1 fold: 1 epoch: 2 - loss:2.289
# phase: 1 fold: 1 epoch: 2 - accuracy:0.141
# saved checkpoint: /home/inflaton/code/courses/cs701/data/checkpoints_phase_1/checkpoint-002.pth
# Starting epoch 3
# phase: 1 fold: 1 epoch: 3 - loss:2.271
# phase: 1 fold: 1 epoch: 3 - accuracy:0.249
# saved checkpoint: /home/inflaton/code/courses/cs701/data/checkpoints_phase_1/checkpoint-003.pth
# Starting epoch 4
# phase: 1 fold: 1 epoch: 4 - loss:2.267
# phase: 1 fold: 1 epoch: 4 - accuracy:0.234
# saved checkpoint: /home/inflaton/code/courses/cs701/data/checkpoints_phase_1/checkpoint-004.pth
# Starting epoch 5
# phase: 1 fold: 1 epoch: 5 - loss:2.253
# phase: 1 fold: 1 epoch: 5 - accuracy:0.240
# saved checkpoint: /home/inflaton/code/courses/cs701/data/checkpoints_phase_1/checkpoint
# saved checkpoint: /home/inflaton/code/courses/cs701/data/checkpoints_phase_2/checkpoint-027.pth
# Starting epoch 28
# phase: 2 fold: 5 epoch:28 - loss:2.129
# phase: 2 fold: 5 epoch:28 - accuracy:0.959
# saved checkpoint: /home/inflaton/code/courses/cs701/data/checkpoints_phase_2/checkpoint-028.pth
# Starting epoch 29
# ...
# Starting epoch 26
# phase:10 fold: 4 epoch:26 - loss:3.998
# phase:10 fold: 4 epoch:26 - accuracy:0.583
# saved checkpoint: /home/inflaton/code/courses/cs701/data/checkpoints_phase_10/checkpoint-026.pth
# Starting epoch 27
# phase:10 fold: 4 epoch:27 - loss:4.039
# phase:10 fold: 4 epoch:27 - accuracy:0.528
# saved checkpoint: /home/inflaton/code/courses/cs701/data/checkpoints_phase_10/checkpoint-027.pth
# Starting epoch 28
# phase:10 fold: 4 epoch:28 - loss:4.020
# phase:10 fold: 4 epoch:28 - accuracy:0.536
# saved checkpoint: /home/inflaton/code/courses/cs701/data/checkpoints_phase_10/checkpoint-028.pth
# Starting epoch 29
# phase:10 fold: 4 epoch:29 - loss:3.966
# phase:10 fold: 4 epoch:29 - accuracy:0.499
# saved checkpoint: /home/inflaton/code/courses/cs701/data/checkpoints_phase_10/checkpoint-029.pth
# Starting epoch 30
# phase:10 fold: 4 epoch:30 - loss:4.006
# phase:10 fold: 4 epoch:30 - accuracy:0.497
# saved checkpoint: /home/inflaton/code/courses/cs701/data/checkpoints_phase_10/checkpoint-030.pth
# phase:  10
# classes:  100
# fold:  5
# loaded checkpoint: /home/inflaton/code/courses/cs701/data/checkpoints_phase_10/checkpoint-018.pth
# Starting epoch 1
# phase:10 fold: 5 epoch: 1 - loss:3.991
# phase:10 fold: 5 epoch: 1 - accuracy:0.541
# saved checkpoint: /home/inflaton/code/courses/cs701/data/checkpoints_phase_10/checkpoint-001.pth
# Starting epoch 2
# phase:10 fold: 5 epoch: 2 - loss:4.004
# phase:10 fold: 5 epoch: 2 - accuracy:0.577
# saved checkpoint: /home/inflaton/code/courses/cs701/data/checkpoints_phase_10/checkpoint-002.pth
# Starting epoch 3
# phase:10 fold: 5 epoch: 3 - loss:4.014
# phase:10 fold: 5 epoch: 3 - accuracy:0.545
# saved checkpoint: /home/inflaton/code/courses/cs701/data/checkpoints_phase_10/checkpoint-003.pth
# Starting epoch 4
# phase:10 fold: 5 epoch: 4 - loss:4.027
# phase:10 fold: 5 epoch: 4 - accuracy:0.568
# saved checkpoint: /home/inflaton/code/courses/cs701/data/checkpoints_phase_10/checkpoint-004.pth
# Starting epoch 5
# phase:10 fold: 5 epoch: 5 - loss:4.020
# phase:10 fold: 5 epoch: 5 - accuracy:0.506
# saved checkpoint: /home/inflaton/code/courses/cs701/data/checkpoints_phase_10/checkpoint-005.pth
# Starting epoch 6
# phase:10 fold: 5 epoch: 6 - loss:4.017
# phase:10 fold: 5 epoch: 6 - accuracy:0.497
# saved checkpoint: /home/inflaton/code/courses/cs701/data/checkpoints_phase_10/checkpoint-006.pth
# Starting epoch 7
# phase:10 fold: 5 epoch: 7 - loss:4.033
# phase:10 fold: 5 epoch: 7 - accuracy:0.554
# saved checkpoint: /home/inflaton/code/courses/cs701/data/checkpoints_phase_10/checkpoint-007.pth
# Starting epoch 8
# phase:10 fold: 5 epoch: 8 - loss:4.032
# phase:10 fold: 5 epoch: 8 - accuracy:0.479
# saved checkpoint: /home/inflaton/code/courses/cs701/data/checkpoints_phase_10/checkpoint-008.pth
# Starting epoch 9
# phase:10 fold: 5 epoch: 9 - loss:4.010
# phase:10 fold: 5 epoch: 9 - accuracy:0.555
# saved checkpoint: /home/inflaton/code/courses/cs701/data/checkpoints_phase_10/checkpoint-009.pth
# Starting epoch 10
# phase:10 fold: 5 epoch:10 - loss:4.018
# phase:10 fold: 5 epoch:10 - accuracy:0.518
# saved checkpoint: /home/inflaton/code/courses/cs701/data/checkpoints_phase_10/checkpoint-010.pth
# Starting epoch 11
# phase:10 fold: 5 epoch:11 - loss:4.028
# phase:10 fold: 5 epoch:11 - accuracy:0.501
# saved checkpoint: /home/inflaton/code/courses/cs701/data/checkpoints_phase_10/checkpoint-011.pth
# Starting epoch 12
# phase:10 fold: 5 epoch:12 - loss:4.057
# phase:10 fold: 5 epoch:12 - accuracy:0.457
# saved checkpoint: /home/inflaton/code/courses/cs701/data/checkpoints_phase_10/checkpoint-012.pth
# Starting epoch 13
# phase:10 fold: 5 epoch:13 - loss:4.027
# phase:10 fold: 5 epoch:13 - accuracy:0.542
# saved checkpoint: /home/inflaton/code/courses/cs701/data/checkpoints_phase_10/checkpoint-013.pth
# Starting epoch 14
# phase:10 fold: 5 epoch:14 - loss:4.049
# phase:10 fold: 5 epoch:14 - accuracy:0.512
# saved checkpoint: /home/inflaton/code/courses/cs701/data/checkpoints_phase_10/checkpoint-014.pth
# Starting epoch 15
# phase:10 fold: 5 epoch:15 - loss:4.027
# phase:10 fold: 5 epoch:15 - accuracy:0.541
# saved checkpoint: /home/inflaton/code/courses/cs701/data/checkpoints_phase_10/checkpoint-015.pth
# Starting epoch 16
# phase:10 fold: 5 epoch:16 - loss:3.988
# phase:10 fold: 5 epoch:16 - accuracy:0.582
# saved checkpoint: /home/inflaton/code/courses/cs701/data/checkpoints_phase_10/checkpoint-016.pth
# Starting epoch 17
# phase:10 fold: 5 epoch:17 - loss:4.004
# phase:10 fold: 5 epoch:17 - accuracy:0.545
# saved checkpoint: /home/inflaton/code/courses/cs701/data/checkpoints_phase_10/checkpoint-017.pth
# Starting epoch 18
# phase:10 fold: 5 epoch:18 - loss:4.016
# phase:10 fold: 5 epoch:18 - accuracy:0.543
# saved checkpoint: /home/inflaton/code/courses/cs701/data/checkpoints_phase_10/checkpoint-018.pth
# Starting epoch 19
# phase:10 fold: 5 epoch:19 - loss:4.044
# phase:10 fold: 5 epoch:19 - accuracy:0.532
# saved checkpoint: /home/inflaton/code/courses/cs701/data/checkpoints_phase_10/checkpoint-019.pth
# Starting epoch 20
# phase:10 fold: 5 epoch:20 - loss:4.047
# phase:10 fold: 5 epoch:20 - accuracy:0.516
# saved checkpoint: /home/inflaton/code/courses/cs701/data/checkpoints_phase_10/checkpoint-020.pth
# Starting epoch 21
# phase:10 fold: 5 epoch:21 - loss:4.065
# phase:10 fold: 5 epoch:21 - accuracy:0.469
# saved checkpoint: /home/inflaton/code/courses/cs701/data/checkpoints_phase_10/checkpoint-021.pth
# Starting epoch 22
# phase:10 fold: 5 epoch:22 - loss:4.050
# phase:10 fold: 5 epoch:22 - accuracy:0.537
# saved checkpoint: /home/inflaton/code/courses/cs701/data/checkpoints_phase_10/checkpoint-022.pth
# Starting epoch 23
# phase:10 fold: 5 epoch:23 - loss:4.052
# phase:10 fold: 5 epoch:23 - accuracy:0.528
# saved checkpoint: /home/inflaton/code/courses/cs701/data/checkpoints_phase_10/checkpoint-023.pth
# Starting epoch 24
# phase:10 fold: 5 epoch:24 - loss:4.033
# phase:10 fold: 5 epoch:24 - accuracy:0.530
# saved checkpoint: /home/inflaton/code/courses/cs701/data/checkpoints_phase_10/checkpoint-024.pth
# Starting epoch 25
# phase:10 fold: 5 epoch:25 - loss:4.041
# phase:10 fold: 5 epoch:25 - accuracy:0.538
# saved checkpoint: /home/inflaton/code/courses/cs701/data/checkpoints_phase_10/checkpoint-025.pth
# Starting epoch 26
# phase:10 fold: 5 epoch:26 - loss:3.997
# phase:10 fold: 5 epoch:26 - accuracy:0.417
# saved checkpoint: /home/inflaton/code/courses/cs701/data/checkpoints_phase_10/checkpoint-026.pth
# Starting epoch 27
# phase:10 fold: 5 epoch:27 - loss:4.012
# phase:10 fold: 5 epoch:27 - accuracy:0.325
# saved checkpoint: /home/inflaton/code/courses/cs701/data/checkpoints_phase_10/checkpoint-027.pth
# Starting epoch 28
# phase:10 fold: 5 epoch:28 - loss:4.006
# phase:10 fold: 5 epoch:28 - accuracy:0.397
# saved checkpoint: /home/inflaton/code/courses/cs701/data/checkpoints_phase_10/checkpoint-028.pth
# Starting epoch 29
# phase:10 fold: 5 epoch:29 - loss:3.978
# phase:10 fold: 5 epoch:29 - accuracy:0.462
# saved checkpoint: /home/inflaton/code/courses/cs701/data/checkpoints_phase_10/checkpoint-029.pth
# Starting epoch 30
# phase:10 fold: 5 epoch:30 - loss:3.979
# phase:10 fold: 5 epoch:30 - accuracy:0.498
# saved checkpoint: /home/inflaton/code/courses/cs701/data/checkpoints_phase_10/checkpoint-030.pth
# Training is completed in 2.0 hours, 32.0 minutes, 38.123 seconds
# Current Directory:
# /home/inflaton/code/courses/cs701
# Sun Oct 22 08:41:22 2023
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.103                Driver Version: 537.13       CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce RTX 4080 ...    On  | 00000000:01:00.0 Off |                  N/A |
# | N/A   74C    P4              30W / 150W |      0MiB / 12282MiB |      1%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+
# Linux Donghao-Win 5.10.102.1-microsoft-standard-WSL2 #1 SMP Wed Mar 2 00:30:59 UTC 2022 x86_64 x86_64 x86_64 GNU/Linux
# PRETTY_NAME="Ubuntu 22.04.3 LTS"
# NAME="Ubuntu"
# VERSION_ID="22.04"
# VERSION="22.04.3 LTS (Jammy Jellyfish)"
# VERSION_CODENAME=jammy
# ID=ubuntu
# ID_LIKE=debian
# HOME_URL="https://www.ubuntu.com/"
# SUPPORT_URL="https://help.ubuntu.com/"
# BUG_REPORT_URL="https://bugs.launchpad.net/ubuntu/"
# PRIVACY_POLICY_URL="https://www.ubuntu.com/legal/terms-and-policies/privacy-policy"
# UBUNTU_CODENAME=jammy
# Architecture:            x86_64
#   CPU op-mode(s):        32-bit, 64-bit
#   Address sizes:         39 bits physical, 48 bits virtual
#   Byte Order:            Little Endian
# CPU(s):                  24
#   On-line CPU(s) list:   0-23
# Vendor ID:               GenuineIntel
#   Model name:            13th Gen Intel(R) Core(TM) i9-13900HX
#     CPU family:          6
#     Model:               183
#     Thread(s) per core:  2
#     Core(s) per socket:  12
#     Socket(s):           1
#     Stepping:            1
#     BogoMIPS:            4838.39
#     Flags:               fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mc
#                          a cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscal
#                          l nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopo
#                          logy tsc_reliable nonstop_tsc cpuid pni pclmulqdq vmx s
#                          sse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt ts
#                          c_deadline_timer aes xsave avx f16c rdrand hypervisor l
#                          ahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb
#                          stibp ibrs_enhanced tpr_shadow vnmi ept vpid ept_ad fsg
#                          sbase tsc_adjust bmi1 avx2 smep bmi2 erms invpcid rdsee
#                          d adx smap clflushopt clwb sha_ni xsaveopt xsavec xgetb
#                          v1 xsaves umip waitpkg gfni vaes vpclmulqdq rdpid movdi
#                          ri movdir64b fsrm serialize flush_l1d arch_capabilities
# Virtualization features:
#   Virtualization:        VT-x
#   Hypervisor vendor:     Microsoft
#   Virtualization type:   full
# Caches (sum of all):
#   L1d:                   576 KiB (12 instances)
#   L1i:                   384 KiB (12 instances)
#   L2:                    24 MiB (12 instances)
#   L3:                    36 MiB (1 instance)
# Vulnerabilities:
#   Itlb multihit:         Not affected
#   L1tf:                  Not affected
#   Mds:                   Not affected
#   Meltdown:              Not affected
#   Spec store bypass:     Mitigation; Speculative Store Bypass disabled via prctl
#                           and seccomp
#   Spectre v1:            Mitigation; usercopy/swapgs barriers and __user pointer
#                           sanitization
#   Spectre v2:            Mitigation; Enhanced IBRS, IBPB conditional, RSB fillin
#                          g
#   Srbds:                 Not affected
#   Tsx async abort:       Not affected
# MemTotal:       49334668 kB
# Running python validate.py --batch=32 --phase=1
# device:  cuda
# classes:  10
# checkpoint:  0
# batch:  32
# phase:  1
# loaded checkpoint: /home/inflaton/code/courses/cs701/data/checkpoints_phase_1/checkpoint-007.pth
# accuracy:  1.0
# not found:  data/Val/789.jpg
# 886 results saved to: /home/inflaton/code/courses/cs701/results/result_1.txt
# Validation is completed in 0.0 hours, 0.0 minutes, 7.443 seconds
# Running python validate.py --batch=32 --phase=2
# device:  cuda
# classes:  20
# checkpoint:  0
# batch:  32
# phase:  2
# loaded checkpoint: /home/inflaton/code/courses/cs701/data/checkpoints_phase_2/checkpoint-015.pth
# accuracy:  0.9720183198444068
# not found:  data/Val/789.jpg
# 886 results saved to: /home/inflaton/code/courses/cs701/results/result_2.txt
# Validation is completed in 0.0 hours, 0.0 minutes, 7.444 seconds
# Running python validate.py --batch=32 --phase=3
# device:  cuda
# classes:  30
# checkpoint:  0
# batch:  32
# phase:  3
# loaded checkpoint: /home/inflaton/code/courses/cs701/data/checkpoints_phase_3/checkpoint-004.pth
# accuracy:  0.921921668075514
# not found:  data/Val/789.jpg
# 886 results saved to: /home/inflaton/code/courses/cs701/results/result_3.txt
# Validation is completed in 0.0 hours, 0.0 minutes, 7.341 seconds
# Running python validate.py --batch=32 --phase=4
# device:  cuda
# classes:  40
# checkpoint:  0
# batch:  32
# phase:  4
# loaded checkpoint: /home/inflaton/code/courses/cs701/data/checkpoints_phase_4/checkpoint-017.pth
# accuracy:  0.8922258297258296
# not found:  data/Val/789.jpg
# 886 results saved to: /home/inflaton/code/courses/cs701/results/result_4.txt
# Validation is completed in 0.0 hours, 0.0 minutes, 8.152 seconds
# Running python validate.py --batch=32 --phase=5
# device:  cuda
# classes:  50
# checkpoint:  0
# batch:  32
# phase:  5
# loaded checkpoint: /home/inflaton/code/courses/cs701/data/checkpoints_phase_5/checkpoint-006.pth
# accuracy:  0.8591015837005141
# not found:  data/Val/789.jpg
# 886 results saved to: /home/inflaton/code/courses/cs701/results/result_5.txt
# Validation is completed in 0.0 hours, 0.0 minutes, 7.683 seconds
# Running python validate.py --batch=32 --phase=6
# device:  cuda
# classes:  60
# checkpoint:  0
# batch:  32
# phase:  6
# loaded checkpoint: /home/inflaton/code/courses/cs701/data/checkpoints_phase_6/checkpoint-013.pth
# accuracy:  0.8125282973906827
# not found:  data/Val/789.jpg
# 886 results saved to: /home/inflaton/code/courses/cs701/results/result_6.txt
# Validation is completed in 0.0 hours, 0.0 minutes, 7.431 seconds
# Running python validate.py --batch=32 --phase=7
# device:  cuda
# classes:  70
# checkpoint:  0
# batch:  32
# phase:  7
# loaded checkpoint: /home/inflaton/code/courses/cs701/data/checkpoints_phase_7/checkpoint-024.pth
# accuracy:  0.818444300797242
# not found:  data/Val/789.jpg
# 886 results saved to: /home/inflaton/code/courses/cs701/results/result_7.txt
# Validation is completed in 0.0 hours, 0.0 minutes, 7.478 seconds
# Running python validate.py --batch=32 --phase=8
# device:  cuda
# classes:  80
# checkpoint:  0
# batch:  32
# phase:  8
# loaded checkpoint: /home/inflaton/code/courses/cs701/data/checkpoints_phase_8/checkpoint-010.pth
# accuracy:  0.7177698270721526
# not found:  data/Val/789.jpg
# 886 results saved to: /home/inflaton/code/courses/cs701/results/result_8.txt
# Validation is completed in 0.0 hours, 0.0 minutes, 7.381 seconds
# Running python validate.py --batch=32 --phase=9
# device:  cuda
# classes:  90
# checkpoint:  0
# batch:  32
# phase:  9
# loaded checkpoint: /home/inflaton/code/courses/cs701/data/checkpoints_phase_9/checkpoint-021.pth
# accuracy:  0.696900499330167
# not found:  data/Val/789.jpg
# 886 results saved to: /home/inflaton/code/courses/cs701/results/result_9.txt
# Validation is completed in 0.0 hours, 0.0 minutes, 7.192 seconds
# Running python validate.py --batch=32 --phase=10
# device:  cuda
# classes:  100
# checkpoint:  0
# batch:  32
# phase:  10
# loaded checkpoint: /home/inflaton/code/courses/cs701/data/checkpoints_phase_10/checkpoint-016.pth
# accuracy:  0.5822766346256278
# not found:  data/Val/789.jpg
# 886 results saved to: /home/inflaton/code/courses/cs701/results/result_10.txt
# Validation is completed in 0.0 hours, 0.0 minutes, 7.180 seconds

# %%
# !./validate.sh
# Out:
# Current Directory:
# /home/inflaton/code/courses/cs701
# Sun Oct 22 06:03:33 2023
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.103                Driver Version: 537.13       CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce RTX 4080 ...    On  | 00000000:01:00.0 Off |                  N/A |
# | N/A   51C    P8               2W / 150W |      0MiB / 12282MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+
# Linux Donghao-Win 5.10.102.1-microsoft-standard-WSL2 #1 SMP Wed Mar 2 00:30:59 UTC 2022 x86_64 x86_64 x86_64 GNU/Linux
# PRETTY_NAME="Ubuntu 22.04.3 LTS"
# NAME="Ubuntu"
# VERSION_ID="22.04"
# VERSION="22.04.3 LTS (Jammy Jellyfish)"
# VERSION_CODENAME=jammy
# ID=ubuntu
# ID_LIKE=debian
# HOME_URL="https://www.ubuntu.com/"
# SUPPORT_URL="https://help.ubuntu.com/"
# BUG_REPORT_URL="https://bugs.launchpad.net/ubuntu/"
# PRIVACY_POLICY_URL="https://www.ubuntu.com/legal/terms-and-policies/privacy-policy"
# UBUNTU_CODENAME=jammy
# Architecture:            x86_64
#   CPU op-mode(s):        32-bit, 64-bit
#   Address sizes:         39 bits physical, 48 bits virtual
#   Byte Order:            Little Endian
# CPU(s):                  24
#   On-line CPU(s) list:   0-23
# Vendor ID:               GenuineIntel
#   Model name:            13th Gen Intel(R) Core(TM) i9-13900HX
#     CPU family:          6
#     Model:               183
#     Thread(s) per core:  2
#     Core(s) per socket:  12
#     Socket(s):           1
#     Stepping:            1
#     BogoMIPS:            4838.39
#     Flags:               fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mc
#                          a cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscal
#                          l nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopo
#                          logy tsc_reliable nonstop_tsc cpuid pni pclmulqdq vmx s
#                          sse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt ts
#                          c_deadline_timer aes xsave avx f16c rdrand hypervisor l
#                          ahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb
#                          stibp ibrs_enhanced tpr_shadow vnmi ept vpid ept_ad fsg
#                          sbase tsc_adjust bmi1 avx2 smep bmi2 erms invpcid rdsee
#                          d adx smap clflushopt clwb sha_ni xsaveopt xsavec xgetb
#                          v1 xsaves umip waitpkg gfni vaes vpclmulqdq rdpid movdi
#                          ri movdir64b fsrm serialize flush_l1d arch_capabilities
# Virtualization features:
#   Virtualization:        VT-x
#   Hypervisor vendor:     Microsoft
#   Virtualization type:   full
# Caches (sum of all):
#   L1d:                   576 KiB (12 instances)
#   L1i:                   384 KiB (12 instances)
#   L2:                    24 MiB (12 instances)
#   L3:                    36 MiB (1 instance)
# Vulnerabilities:
#   Itlb multihit:         Not affected
#   L1tf:                  Not affected
#   Mds:                   Not affected
#   Meltdown:              Not affected
#   Spec store bypass:     Mitigation; Speculative Store Bypass disabled via prctl
#                           and seccomp
#   Spectre v1:            Mitigation; usercopy/swapgs barriers and __user pointer
#                           sanitization
#   Spectre v2:            Mitigation; Enhanced IBRS, IBPB conditional, RSB fillin
#                          g
#   Srbds:                 Not affected
#   Tsx async abort:       Not affected
# MemTotal:       49334668 kB
# Running python validate.py --batch=32 --phase=1
# device:  cuda
# classes:  10
# checkpoint:  0
# batch:  32
# phase:  1
# loaded checkpoint: /home/inflaton/code/courses/cs701/data/checkpoints_phase_1/checkpoint-007.pth
# accuracy:  1.0
# not found:  data/Val/789.jpg
# 886 results saved to: /home/inflaton/code/courses/cs701/results/result_1.txt
# Validation is completed in 0.0 hours, 0.0 minutes, 7.813 seconds
# Running python validate.py --batch=32 --phase=2
# device:  cuda
# classes:  20
# checkpoint:  0
# batch:  32
# phase:  2
# loaded checkpoint: /home/inflaton/code/courses/cs701/data/checkpoints_phase_2/checkpoint-015.pth
# accuracy:  0.9720183198444068
# not found:  data/Val/789.jpg
# 886 results saved to: /home/inflaton/code/courses/cs701/results/result_2.txt
# Validation is completed in 0.0 hours, 0.0 minutes, 7.736 seconds
# Running python validate.py --batch=32 --phase=3
# device:  cuda
# classes:  30
# checkpoint:  0
# batch:  32
# phase:  3
# loaded checkpoint: /home/inflaton/code/courses/cs701/data/checkpoints_phase_3/checkpoint-004.pth
# accuracy:  0.921921668075514
# not found:  data/Val/789.jpg
# 886 results saved to: /home/inflaton/code/courses/cs701/results/result_3.txt
# Validation is completed in 0.0 hours, 0.0 minutes, 7.457 seconds
# Running python validate.py --batch=32 --phase=4
# device:  cuda
# classes:  40
# checkpoint:  0
# batch:  32
# phase:  4
# loaded checkpoint: /home/inflaton/code/courses/cs701/data/checkpoints_phase_4/checkpoint-017.pth
# accuracy:  0.8922258297258296
# not found:  data/Val/789.jpg
# 886 results saved to: /home/inflaton/code/courses/cs701/results/result_4.txt
# Validation is completed in 0.0 hours, 0.0 minutes, 7.510 seconds
# Running python validate.py --batch=32 --phase=5
# device:  cuda
# classes:  50
# checkpoint:  0
# batch:  32
# phase:  5
# loaded checkpoint: /home/inflaton/code/courses/cs701/data/checkpoints_phase_5/checkpoint-006.pth
# accuracy:  0.8591015837005141
# not found:  data/Val/789.jpg
# 886 results saved to: /home/inflaton/code/courses/cs701/results/result_5.txt
# Validation is completed in 0.0 hours, 0.0 minutes, 7.419 seconds
# Running python validate.py --batch=32 --phase=6
# device:  cuda
# classes:  60
# checkpoint:  0
# batch:  32
# phase:  6
# loaded checkpoint: /home/inflaton/code/courses/cs701/data/checkpoints_phase_6/checkpoint-013.pth
# accuracy:  0.8125282973906827
# not found:  data/Val/789.jpg
# 886 results saved to: /home/inflaton/code/courses/cs701/results/result_6.txt
# Validation is completed in 0.0 hours, 0.0 minutes, 7.299 seconds
# Running python validate.py --batch=32 --phase=7
# device:  cuda
# classes:  70
# checkpoint:  0
# batch:  32
# phase:  7
# loaded checkpoint: /home/inflaton/code/courses/cs701/data/checkpoints_phase_7/checkpoint-024.pth
# accuracy:  0.818444300797242
# not found:  data/Val/789.jpg
# 886 results saved to: /home/inflaton/code/courses/cs701/results/result_7.txt
# Validation is completed in 0.0 hours, 0.0 minutes, 7.352 seconds
# Running python validate.py --batch=32 --phase=8
# device:  cuda
# classes:  80
# checkpoint:  0
# batch:  32
# phase:  8
# loaded checkpoint: /home/inflaton/code/courses/cs701/data/checkpoints_phase_8/checkpoint-010.pth
# accuracy:  0.7177698270721526
# not found:  data/Val/789.jpg
# 886 results saved to: /home/inflaton/code/courses/cs701/results/result_8.txt
# Validation is completed in 0.0 hours, 0.0 minutes, 7.387 seconds
# Running python validate.py --batch=32 --phase=9
# device:  cuda
# classes:  90
# checkpoint:  0
# batch:  32
# phase:  9
# loaded checkpoint: /home/inflaton/code/courses/cs701/data/checkpoints_phase_9/checkpoint-021.pth
# accuracy:  0.696900499330167
# not found:  data/Val/789.jpg
# 886 results saved to: /home/inflaton/code/courses/cs701/results/result_9.txt
# Validation is completed in 0.0 hours, 0.0 minutes, 7.240 seconds
# Running python validate.py --batch=32 --phase=10
# device:  cuda
# classes:  100
# checkpoint:  0
# batch:  32
# phase:  10
# loaded checkpoint: /home/inflaton/code/courses/cs701/data/checkpoints_phase_10/checkpoint-016.pth
# accuracy:  0.5822766346256278
# not found:  data/Val/789.jpg
# 886 results saved to: /home/inflaton/code/courses/cs701/results/result_10.txt
# Validation is completed in 0.0 hours, 0.0 minutes, 7.266 seconds
